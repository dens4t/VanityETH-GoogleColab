# %% [markdown]
# <a href="https://colab.research.google.com/github/densat98/VanityETH-GoogleColab/blob/main/VanityETH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/antonio-fr/Vanityreum.git
# Out:
# Cloning into 'Vanityreum'...
# remote: Enumerating objects: 86, done.
# remote: Total 86 (delta 0), reused 0 (delta 0), pack-reused 86
# Unpacking objects: 100% (86/86), done.

# %%
cd /content/Vanityreum/
# Out:
# /content/Vanityreum

# %%
# !python2.7 Vanityreum.py dead
# Out:
# Generate new Ethereum address from random or vanity (FirstBits)
#
# Vanity Mode, please Wait ...
# Press CTRL+C to stop searching
# Search in Progress ..  33.3  per second
# Mean remaining time : 32 minutes and 45 seconds
#
# Search in Progress ..  33.6  per second
# Mean remaining time : 32 minutes and 25 seconds
#
# Search in Progress ..  33.8  per second
# Mean remaining time : 32 minutes and 5 seconds
#
# Search in Progress ..  33.7  per second
# Mean remaining time : 32 minutes and 6 seconds
#
# Search in Progress ..  33.7  per second
# Mean remaining time : 32 minutes and 7 seconds
#
# Search in Progress ..  33.7  per second
# Mean remaining time : 32 minutes and 2 seconds
#
# Search in Progress ..  33.9  per second
# Mean remaining time : 31 minutes and 46 seconds
#
# Search in Progress ..  33.9  per second
# Mean remaining time : 31 minutes and 44 seconds
#
# Search in Progress ..  33.6  per second
# Mean remaining time : 31 minutes and 55 seconds
#
# ...

# %%
# !vanityeth -n 10 -i deadbeef
